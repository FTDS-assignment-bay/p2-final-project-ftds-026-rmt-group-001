# %%
import pandas as pd

# %%
df1 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_1_a.csv')
df2 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_1_b.csv')
df3 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_2.csv')
df5 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_3_1001-1101.csv')
df6 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_3_1101-1201.csv')
df7 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_3_1201-1301.csv')
df8 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_3_1301-1401.csv')
df9 = pd.read_csv('./datasets/rumah123_data_single_raw_fix_part_3_1401-1467.csv')

# %%
# Concatenate the datasets
concatenated_df = pd.concat([df1, df2, df3, df5, df6, df7, df8, df9], ignore_index=True)

# %%
df = pd.concat([df1, df2, df3, df5, df6, df7, df8, df9], join='inner')

# %%
df
# Out:
#     Unnamed: 0                                              Judul  \
# 0            0  RUMAH 2 LANTAI TENGAH KOTA PERUMAHAN BUKIT DAM...
# 1            1  Rumah Luas Lokasi Strategis di Gunung Samarind...
# 2            2  Rumah Minimalis Baru Renovasi Untuk Keluarga M...
# 3            3  DIJUAL CEPAT RUMAH DI JALAN SWADAYA, KARANG RE...
# 4            4       Rumah Minimalis Modern Smart Home Tanah Luas
# ..         ...                                                ...
# 60        1462             Rumah Murah Harga Nego Dalam Perumahan
# 61        1463                        Perumahan Elit Pupuk Kaltim
# 62        1464                  Rumah Baru Minimalis Kpr Tanpa Dp
# 63        1465                             BALIKPAPAN POKA (Y140)
# 64        1466                            Rumah cantik tanah luas
#
#             Harga                          Lokasi  Kamar Tidur  Kamar Mandi  \
# 0   Rp 1,5 Miliar  Balikpapan Selatan, Balikpapan          5.0          3.0
# ...

# %%
# sort row by unnamed column
df = df.sort_values(by='Unnamed: 0')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1413 entries, 0 to 64
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1413 non-null   int64
#  1   Judul                1413 non-null   object
#  2   Harga                1413 non-null   object
#  3   Lokasi               1413 non-null   object
#  4   Kamar Tidur          1362 non-null   float64
#  5   Kamar Mandi          1361 non-null   float64
#  6   Luas Tanah           1413 non-null   object
#  7   Luas Bangunan        1413 non-null   object
#  8   Carport              253 non-null    float64
#  9   Tipe Properti        1413 non-null   object
#  10  Sertifikat           1412 non-null   object
#  11  Daya Listrik         1362 non-null   object
#  12  Kamar Pembantu       242 non-null    float64
#  13  Dapur                228 non-null    float64
#  14  Ruang Makan          696 non-null    object
# ...

# %%
df.to_csv('./datasets/rumah123_data_single_raw_concated.csv', index=False)
